# %% [markdown]
#
#
# Universidad Autónoma de Bucaramanga
#
# Laboratorio de mecánica
#
# Informe 11 – Colisiones
#
#
#
# Presenta:
# Nicolás López
# Armith Trujillo
# Juan Arenales
#
#
#
# 19 de octubre
# 2022
#
# 	Objetivo
#
# Durante la ejecución de este experimento, se buscaba hallar los valores y formulas para obtener una dos (2) tipos de colisiones, elástica e inelástica, aplicando los conocimientos previos dados antes del experimento.
#
#
# 	Metodología
#
# Con el uso de dos (2) “vehículos”, pesas de cien (100) gramos, un riel de aire y lectores de velocidad exactos, se realizaban ciertos lanzamientos para colisionar estos vehículos entre si y de esta manera hallar si su colisión fue elástica (en donde tras la colisión se separan) o inelástica (en donde tras la colisión se quedan juntos).
#
#
# 	Marco teórico
#
# 	Colisiones
#
# Cuando dos o más cuerpos se aproximan entre sí, entre ellos actúan fuerzas internas que hacen que su momento lineal y su energía varíen, produciéndose un intercambio entre ellos de ambas magnitudes. En este caso se dice que entre los cuerpos se ha producido una colisión o choque.
#
# 	Coeficiente de restitución
#
# Cuando dos cuerpos chocan, sus materiales pueden comportarse de distinta manera según las fuerzas de restitución que actúen sobre los mismos. Hay materiales cuyas fuerzas restituirán completamente la forma de los cuerpos sin haber cambio de forma ni energía cinética perdida en forma de calor, etc. En otros tipos de choque los materiales cambian su forma, liberan calor, etc., modificándose la energía cinética total. Se define entonces un coeficiente de restitución (K) que evalúa esta pérdida o no de energía cinética, según las fuerzas de restitución y la elasticidad de los materiales.
#
# Coeficiente de Restitución
# K = Coeficiente de restitución [sin unidad]
# V1(0), V2(0) = Velocidades de los cuerpos 1 y 2 antes del choque
# V1(f), V2(f) = Velocidades de los cuerpos 1 y 2 después del choque
# K es un número que varía entre 0 y 1.
# Si K = 0 choque perfectamente inelástico.
# Si 0 < K < 1 choque parcialmente elástico o inelástico.
# Si K = 1 choque perfectamente elástico.
#
# 	Tipos de colisiones
#
# Choque elástico
# En un choque elástico, además de la cantidad de movimiento, también se conserva la energía cinética total del sistema.
# También se conservan las formas de los cuerpos y no hay energía perdida por rozamiento, calor, etc. El coeficiente de restitución en este tipo de choque vale 1.
#
#
# K = Coeficiente de restitución [sin unidad]
# Ec1(0), Ec2(0) = Energía cinética inicial de los cuerpos 1 y 2 [J]
# Ec1(f), Ec2(f) = Energía cinética final de los cuerpos 1 y 2 [J]
# Choque inelástico o semi elástico
# En la mayoría de los casos reales actúan fuerzas que no restituyen completamente las formas, habiendo pérdidas de energía cinética. Esto es cuando K tiene valores mayores que 0 y menores que 1. En ese caso decimos que el choque es inelástico o semi elástico.
#
# Choque perfectamente inelástico
# El choque perfectamente inelástico se da cuando ambos cuerpos quedan pegados, teniendo una sola masa luego del choque. Al haber un cambio de forma no se conserva la energía cinética de los cuerpos. El coeficiente de restitución en este tipo de choque vale 0.
#
#
# 	Energía cinética
#
# Definimos la energía cinética como aquella que posee un cuerpo por el hecho de moverse. Su valor viene dado por: E_C=1/2 mV^2
# Donde:
# Ec: Es la energía cinética del cuerpo en movimiento en Julios (J).
# m: Masa del cuerpo en movimiento en Kilogramos (Kg)
# v: Valor de la velocidad del cuerpo en movimiento en metros por segundo (m/s)
#
# 	Momento lineal
#
# El Momento lineal es una magnitud vectorial que nos ayuda a estudiar las interacciones entre objetos. El momento lineal también es conocido como: Cantidad de Movimiento
# El momento lineal es una característica que un objeto o sistema tiene relacionado a su masa y velocidad.
#
# 	Principio de Conservación del Momento Lineal
#
# El principio de conservación del momento lineal, también conocido como principio de conservación de la cantidad de movimiento, establece que si la resultante de las fuerzas que actúan sobre un cuerpo o sistema es nula, su momento lineal permanece constante en el tiempo.
#
#
#
# 	Datos
#
# 	Tabla de datos y resultados
#
#
#
# 	Análisis de resultados
#
# 	En la única tabla del documento, podemos apreciar once (11) tipos de datos distintos, obtenidos durante la ejecución del experimento. Observamos que se realizaron tres (3) colisiones donde dos (2) de ellas son elásticas y la última es inelástica, (m1) es la masa del vehículo uno (1) la cual con cada colisión fue variando de peso, (m2) es la masa del vehículo dos (2) la cual no tuvo variación en las tres (3) colisiones. (v1, v2) es la velocidad registrada de los vehículos momentos antes de su colisión, podemos observar que en las colisiones dos (2) y tres (3) la velocidad del vehículo uno (1) (v1) es cero (0), esto se debe a que se buscaba una colisión con dicho vehículo estático. (u1, u2) son los valores registrados de la velocidad de ambos vehículos justo después de la colisión. Observamos (P), el cual es la cantidad de movimiento lineal, o momentum, se buscaba que P antes fuera igual a P después ya que para un sistema aislado el momentum permanece constante, este fue hallado mediante P=(m_(1^* ) V_1)/(m_2*V_2 ) y P=(m_1*U_1)/(m_(2^* ) U_2 ) respectivamente a P antes y P después. (E) es la energía cinética de los vehículos antes y después de las colisiones en cada caso la cual se halló con E_c=1/2 (m_1*V_1^2+m_(2^* ) V_2^2 ) y E_c=1/2 (m_1*U_1^2+m_(2^* ) U_2^2 ) respectivamente a la energía antes y después de las colisiones. Y por último tenemos el coeficiente el cual es el coeficiente de restitución el cual fue hallado mediante ⅇ=(U_2-U_1)/(V_1-V_2 ).
#
#
# 	Conclusiones
#
# 	Se logró obtener el coeficiente de restitución de cada colisión, tomando en cuenta las explicaciones previas a la ejecución del experimento, hallando dos (2) colisiones parcialmente elásticas y una (1) colision parcialmente inelástica. Se trataba de hallar colisiones ideales, sin embargo debido a variaciones desconocidas durante el experimento, los resultados de estas colisiones fueron parciales y no ideales.
#
# 	Bibliografía
#
# 	https://www.fisicalab.com/apartado/energia-cinetica
# 	https://bioprofe.com/colisiones/
# 	https://www.fisicapractica.com/coeficiente-restitucion.php
# 	https://www.fisicapractica.com/tipos-choque.php
# 	https://www.calculisto.com/topics/sistemas-de-particulas
# 	https://www.fisicalab.com/apartado/conservacion-momento-lineal
